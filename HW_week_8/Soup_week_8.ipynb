# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
import time

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36',
}

# %%
url = "https://techcrunch.com"

# %%
response = requests.get(url, headers=headers, timeout=10)

# %%
html = response.text

# %%
soup = BeautifulSoup(html, 'html.parser')

# %%
titles = soup.find_all('h3')

# %%
print("TechCrunch Article Titles:\n")
# Out:
# TechCrunch Article Titles:

# %%
for i, title in enumerate(titles[:10], 1):
    print(f"{i}. {title.get_text().strip()}")
    time.sleep(1)
# Out:
# 1. Topics
# 2. More from TechCrunch
# 3. Department of Commerce approves Nvidia H200 chip exports to China
# 4. Environmental groups call for halt to new data center construction

# %%
print("\n✓ Done! (with 1 second delays between each title)")
